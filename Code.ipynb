# %%
import mysql.connector
import datetime
from dateutil.relativedelta import relativedelta
import csv
from faker import Faker
import random

# %%
def insert_student(cursor,database_name,table_name,column_names,values):
    try:
        connection = mysql.connector.connect(
            host = 'localhost',
            user = 'root',
            password = 'Raveenr7',
            database = database_name
        )
        cursor = connection.cursor()
        columns = ', '.join(column_names)
        values = ', '.join(values)
        query = f'INSERT INTO {table_name} ({columns}) VALUES ({values})'
        cursor.execute(query)
        connection.commit()
        print("Inserted values")
    except Exception as err:
        print(f"Error: {err}")
    finally:
        cursor.close()
        connection.close()

def show_detail(database_name,table_name,id):
     try:
         connection = mysql.connector.connect(
            host = 'localhost',
            user = 'root',
            password = 'Raveenr7',
            database = database_name
        )
         cursor = connection.cursor()
         query = f"SELECT * FROM {table_name} where id = '{id}'"
         cursor.execute(query)
         result = cursor.fetchall()
         return result
     except Exception as err:
        print(f"Error: {err}")
     finally:
        cursor.close()
        connection.close()
def update_detail(database_name,table_name,id):
     try:
         connection = mysql.connector.connect(
            host = 'localhost',
            user = 'root',
            password = 'Raveenr7',
            database = database_name
        )
         cursor = connection.cursor()
         query = f"SELECT student_name FROM {table_name} where id = '{id}'"
         cursor.execute(query)
         name = cursor.fetchall()
         choice = input('''Do you want to change age? Press 1 
                  Do you want to change guardian? Press 2
                 Do you want to change year? Press 3
                 Do you want to change address? Press 4
                 Do you want to change gender? Press 5
                 Do you want to change mobile_number? Press 6
                 Do you want to change college name? Press 7
                ''')
                
         if choice == 1:
             age = input("Enter the age :")
             query = f"update {table_name} set age = {age} where id = {id}"

         elif choice == 2:
             guardian = input("Enter the guardian's name :")
             query = f"update {table_name} set guardian = {guardian} where id = {id}"

         elif choice == 3:
             year = input("Enter the year :")
             query = f"update {table_name} set year = {year} where id = {id}"

         elif choice == 4:
             guardian = input("Enter the address :")
             query = f"update {table_name} set address = {address} where id = {id}"

         elif choice == 5:
             year = input("Enter the gender :")
             query = f"update {table_name} set year = {gender} where id = {id}"

         elif choice == 6:
             year = input("Enter the mobile number :")
             query = f"update {table_name} set mobile_number = {mobile_number} where id = {id}"

         elif choice == 7:
             year = input("Enter the year :")
             query = f"update {table_name} set year = {year} where id = {id}"
         else:
             print("Invalid choice")
         cursor.execute(query)
         connection.commit()
         if choice <= 7:
             print("Updated the details")
    
     except Exception as err:
        print(f"Error: {err}")
     finally:
        cursor.close()
        connection.close()

def delete_detail(database_name,table_name,id):  
    try:
         connection = mysql.connector.connect(
            host = 'localhost',
            user = 'root',
            password = 'Raveenr7',
            database = database_name
        )
         cursor = connection.cursor()
         query = f"delete from {table_name} where id = {id}"
         cursor.execute(query)
         connection.commit()
    except Exception as err:
        print(f"Error: {err}")
    finally:
        cursor.close()
        connection.close()

def show_details(database_name,table_name,college_name):
     try:
         connection = mysql.connector.connect(
            host = 'localhost',
            user = 'root',
            password = 'Raveenr7',
            database = database_name
        )
         cursor = connection.cursor()
         query = f"SELECT student_name FROM {table_name} where college_name = {college_name}  group by college_name, year, gender"
         cursor.execute(query)
         result = cursor.fetchall()
         print(result)
     except Exception as err:
        print(f"Error: {err}")
     finally:
        cursor.close()
        connection.close()

def change_course(database_name,table_name,id,course_id):  
    try:
         connection = mysql.connector.connect(
            host = 'localhost',
            user = 'root',
            password = 'Raveenr7',
            database = database_name
        )
         cursor = connection.cursor()
         query = f"update {table_name} set course_id = {course_id} where id = {id}"
         cursor.execute(query)
         connection.commit()
         print("Course id changed")
    except Exception as err:
        print(f"Error: {err}")
    finally:
        cursor.close()
        connection.close()

def current_course(database_name,table_name,id):
     try:
         connection = mysql.connector.connect(
            host = 'localhost',
            user = 'root',
            password = 'Raveenr7',
            database = database_name
        )
         cursor = connection.cursor()
         query = f"SELECT course_name FROM {table_name} a join course b on a.course_id = b.course_id on where id = '{id}' "
         cursor.execute(query)
         result = cursor.fetchall()
         print(result)
     except Exception as err:
        print(f"Error: {err}")
     finally:
        cursor.close()
        connection.close()
def insert_teacher(database_name,table_name,columns,values):
    try:
        connection = mysql.connector.connect(
            host = 'localhost',
            user = 'root',
            password = 'Raveenr7',
            database = database_name
        )
        cursor = connection.cursor()
        columns = ', '.join(column_names)
        values = ', '.join(values)
        query = f'INSERT INTO {table_name} ({columns}) VALUES ({values})'
        cursor.execute(query)
        connection.commit()
    except Exception as err:
        print(f"Error: {err}")
    finally:
        cursor.close()
        connection.close()

def update_detail_teacher(database_name,table_name,id):
     try:
         connection = mysql.connector.connect(
            host = 'localhost',
            user = 'root',
            password = 'Raveenr7',
            database = database_name
        )
         cursor = connection.cursor()
         query = f"SELECT teacher_name FROM {table_name} where id = '{id}'"
         cursor.execute(query)
         name = cursor.fetchall()
         choice = input('''Do you want to change age? Press 1 
                  Do you want to change guardian? Press 2
                 Do you want to change year? Press 3
                 Do you want to change address? Press 4
                 Do you want to change gender? Press 5
                 Do you want to change mobile_number? Press 6
                 Do you want to change college name? Press 7
                ''')
                
         if choice == 1:
             age = input("Enter the age :")
             query = f"update {table_name} set age = {age} where id = {id}"

         elif choice == 2:
             guardian = input("Enter the guardian's name :")
             query = f"update {table_name} set guardian = {guardian} where id = {id}"

         elif choice == 3:
             year = input("Enter the year :")
             query = f"update {table_name} set year = {year} where id = {id}"

         elif choice == 4:
             guardian = input("Enter the address :")
             query = f"update {table_name} set address = {address} where id = {id}"

         elif choice == 5:
             year = input("Enter the gender :")
             query = f"update {table_name} set year = {gender} where id = {id}"

         elif choice == 6:
             year = input("Enter the mobile number :")
             query = f"update {table_name} set mobile_number = {mobile_number} where id = {id}"

         elif choice == 7:
             year = input("Enter the year :")
             query = f"update {table_name} set year = {year} where id = {id}"
         else:
             print("Invalid choice")
         cursor.execute(query)
         connection.commit()
         if choice <= 7:
             print("Updated the details")
    
     except Exception as err:
        print(f"Error: {err}")
     finally:
        cursor.close()
        connection.close()

def update_course(database_name,table_name,id):
     try:
         connection = mysql.connector.connect(
            host = 'localhost',
            user = 'root',
            password = 'Raveenr7',
            database = database_name
        )
         cursor = connection.cursor()
         query = f"SELECT year FROM {table_name} where id = '{id}'"
         cursor.execute(query)
         year = cursor.fetchall()
         if year == 1:
             course_id = input ("Enter the new course id")
             query = f"update {table_name} set course_id = {course_id} where id = {id}"
             cursor.execute(query)
             connection.commit()
             print("Updated the course id")
         else :
             print("Student is not from 1st year")
     except Exception as err:
        print(f"Error: {err}")
     finally:
        cursor.close()
        connection.close()

def delete_teacher_detail(database_name,table_name,id):  
    try:
         connection = mysql.connector.connect(
            host = 'localhost',
            user = 'root',
            password = 'Raveenr7',
            database = database_name
        )
         cursor = connection.cursor()
         query = f"delete from {table_name} where id = {id} and (CURRENT_DATE() - INTERVAL '1' MONTH > starting_date)"
         cursor.execute(query)
         if cursor.execute(query):
             print('Deleted')
             connection.commit()
         else:
             print ("Not Deleted")   
    except Exception as err:
        print(f"Error: {err}")
    finally:
        cursor.close()
        connection.close()

def show_teacher_details(database_name,table_name):
     try:
         connection = mysql.connector.connect(
            host = 'localhost',
            user = 'root',
            password = 'Raveenr7',
            database = database_name
        )
         cursor = connection.cursor()
         query = f"SELECT teacher_name FROM {table_name} a join course b on a.course_id = b.course_id group by gender,course_name"
         cursor.execute(query)
         result = cursor.fetchall()
         print(result)
     except Exception as err:
        print(f"Error: {err}")
     finally:
        cursor.close()
        connection.close()


def show_past_courses(database_name,table_name,id):
     try:
         connection = mysql.connector.connect(
            host = 'localhost',
            user = 'root',
            password = 'Raveenr7',
            database = database_name
        )
         cursor = connection.cursor()
         query = f"SELECT distinct course_name FROM {table_name} a join course b on a.course_id = b.course_id where id = {id} and EXTRACT(MONTH FROM CURRENT_DATE()) - EXTRACT(MONTH FROM course_start_date) >= course_duration "
         cursor.execute(query)
         result = cursor.fetchall()
         print(result)
     except Exception as err:
        print(f"Error: {err}")
     finally:
        cursor.close()
        connection.close()

def export_student_data(database_name,table_name,college_name):
     try:
         connection = mysql.connector.connect(
            host = 'localhost',
            user = 'root',
            password = 'Raveenr7',
            database = database_name
        )
         cursor = connection.cursor()
         query = f"SELECT * FROM {table_name} where college_name = {college_name}  group by college_name, year, gender"
         cursor.execute(query)
         result = cursor.fetchall()
         try:
             with open(student_file,'w',newline='') as f:
                csv_writer = csv.writer(f)
                csv_writer.writerow([i[0] for i in cursor.description])
                csv_writer.writerows(result)
                print("Exporting complete")
         except Exception as err:
             print(f"Error: {err}")
     except Exception as err:
        print(f"Error: {err}")
     finally:
        cursor.close()
        connection.close()

def import_student_data(database_name,table_name):
     try:
         connection = mysql.connector.connect(
            host = 'localhost',
            user = 'root',
            password = 'Raveenr7',
            database = database_name
        )
         cursor = connection.cursor()
         try:
             with open(student_file,'r',newline='') as f:
                csv_reader = csv.reader(f)
                next(csv_reader) 
                for row in csv_reader:
                  query = f'INSERT INTO {table_name} VALUES ({", ".join(["%s"]*len(row))})'
                  cursor.execute(query, row)
                connection.commit()
                print(f"Student data imported from {student_file} successfully.")
                 
         except Exception as err:
             print(f"Error: {err}")
             connection.rollback()
     except Exception as err:
        print(f"Error: {err}")
     finally:
        cursor.close()
        connection.close()

def search_student_name(database_name,table_name,student_name):
     try:
         connection = mysql.connector.connect(
            host = 'localhost',
            user = 'root',
            password = 'Raveenr7',
            database = database_name
        )
         cursor = connection.cursor()
         query = f"SELECT * FROM {table_name} where student_name = '{student_name}'"
         cursor.execute(query)
         result = cursor.fetchall()
         print(result)
     except Exception as err:
        print(f"Error: {err}")
     finally:
        cursor.close()
        connection.close()

def search_course(database_name,table_name,course_name):
     try:
         connection = mysql.connector.connect(
            host = 'localhost',
            user = 'root',
            password = 'Raveenr7',
            database = database_name
        )
         cursor = connection.cursor()
         query = f"SELECT a.* FROM {table_name} a join course b on a.course_id,b.course_id where course_name = '{course_name}'"
         cursor.execute(query)
         result = cursor.fetchall()
         print(result)
     except Exception as err:
        print(f"Error: {err}")
     finally:
        cursor.close()
        connection.close()

def search_teacher_name(database_name,table_name,course_name):
     try:
         connection = mysql.connector.connect(
            host = 'localhost',
            user = 'root',
            password = 'Raveenr7',
            database = database_name
        )
         cursor = connection.cursor()
         query = f"SELECT a.* FROM {table_name} a join course b on a.course_id,b.course_id where course_name = '{course_name}'"
         cursor.execute(query)
         result = cursor.fetchall()
         print(result)
     except Exception as err:
        print(f"Error: {err}")
     finally:
        cursor.close()
        connection.close()

# %%
flag = int(input ('''
                 Do you want to add new student? Press 1 \n
                 Do you want to view student details? Press 2 \n
                 Do you want to update student information? Press 3
                 Do you want to delete student record? Press 4
                 Do you want to list all students in the college? Press 5
                 Do you want to assign course to each student (one student can have only 1 course? Press 6
                 Do you want to view student's current course? Press 7
                 Do you want to update student's current course (Only for 1st year students)? Press 8
                 Do you want to view student's past courses (to check if the student has changed the course or is it same.) Press 9
                 Do you want to add new teacher? Press 10
                 Do you want to view teacher details ? Press 11
                 Do you want to update teacher information? Press 12
                 Do you want to delete teacher record (to check only if she/he has worked more than 1 Month)? Press 13
                 Do you want to list all teachers? Press 14
                 Do you want to view teacher's past courses (One teacher should at least teach 2 distinct courses)? Press 15
                 Do you want to Export student data to a CSV file? Press 16
                 Do you want to import student data from a CSV file? Press 17
                 Do you want to search student by name ? Press 18
                 Do you want to search student by course? Press 19
                 Do you want to Search teacher by name? Press 20
                 Do you want to search teacher by course? Press 21
              '''))
if flag ==1 :
    try:
        id = input('Enter the student id')
        student_name= input('Enter the student name')
        age = input('Enter the age')
        guardian = input('Enter the guardian')
        address = input('Enter the address')
        gender = input('Enter the gender')
        mobile_number = input('Enter the mobile number')
        college_name = input('Enter the college name')
        year = input('Enter the year')
        branch = input('Enter the branch in capital')
        course_id = input('Enter the course id')
        course_start_date = input('Enter the course start date')
        starting_date = input('Enter the starting date')

        columns = ['id','student_name','age','guardian','address','gender','mobile_number','college_name','year','course_id','course_start_date','starting_date']
        values = [id,student_name,age,guardian,address,gender,mobile_number,college_name,year,branch,course_id,course_start_date,starting_date]
        insert_student('Student Management System','student',columns,values)
    except Exception as err:
        print(f"Error: {err}")

elif flag == 2:
    try:
        id = input('Enter the student id')
        result = show_details('Student Management System','student',id)
        print(result)
    except Exception as err:
        print(f"Error: {err}")
elif flag == 3:
    try:
        id = input('Enter the student id')
        update_detail('Student Management System','student',id)
    except Exception as err:
        print(f"Error: {err}")
elif flag == 4:
    try:
        id = input('Enter the student id')
        delete_detail('Student Management System','student',id)
    except Exception as err:
        print(f"Error: {err}")
elif flag == 5:
    try:
        college_name = input('Enter the college name')
        show_students('Student Management System','student',college_name)
    except Exception as err:
        print(f"Error: {err}")
elif flag == 6:
    try:
        id = input('Enter the student id')
        course_id = input('Enter the course_id')
        change_course('Student Management System','student',id,course_id)
    except Exception as err:
        print(f"Error: {err}")
elif flag == 7:
    try:
        id = input('Enter the student id')
        current_course('Student Management System','student',id)
    except Exception as err:
        print(f"Error: {err}")

elif flag == 8:
    try:
        id = input('Enter the student id (only 1st years)')
        update_course('Student Management System','student',id)
    except Exception as err:
        print(f"Error: {err}")

elif flag == 9:
    try:
        id = input('Enter the student id')
        show_past_courses('Student Management System','student',id)
    except Exception as err:
        print(f"Error: {err}")
        
elif flag == 10:
    try:
        id = input('Enter the teacher id')
        teacher_name= input('Enter the teacher name')
        age = input('Enter the age')
        guardian = input('Enter the guardian')
        address = input('Enter the address')
        gender = input('Enter the gender')
        mobile_number = input('Enter the mobile number')
        college_name = input('Enter the college name')
        year = input('Enter the year')
        courses = input('Enter the number of courses')
        course_start_date = input('Enter the course start date')
        starting_date = input('Enter the starting date')
        for i in range(courses):
            course_id = input('Enter the course_id')
            columns = ['id','teacher_name','age','guardian','address','gender','mobile_number','college_name','year','course_id','course_start_date','starting_date']
            values = [id,teacher_name,age,guardian,address,gender,mobile_number,college_name,year,course_id,course_start_date,starting_date]
            insert_teacher('Student Management System','teacher',columns,values)  
    except Exception as err:
        print(f"Error: {err}")

elif flag == 11:
    try:
        id = input('Enter the teacher id')
        result = show_detail('Student Management System','teacher',id)
        print(result)
    except Exception as err:
        print(f"Error: {err}")

elif flag == 12:
    try:
        id = input('Enter the teacher id')
        result = update_detail_teacher('Student Management System','teacher',id)
        print(result)
    except Exception as err:
        print(f"Error: {err}")

elif flag == 13:
    try:
        id = input('Enter the teacher id')
        result = delete_teacher_detail('Student Management System','teacher',id)
        print(result)
    except Exception as err:
        print(f"Error: {err}")

elif flag == 14:
    try:
        show_teacher_details('Student Management System','teacher')
    except Exception as err:
        print(f"Error: {err}")

elif flag == 15:
    try:
        id = input ("Enter teacher's id")
        show_past_courses('Student Management System','teacher',id)
    except Exception as err:
        print(f"Error: {err}")

elif flag == 16:
    try:
        college_name = input("Enter the college name whose student data is required")
        export_student_data('Student Management System','student',college_name)
    except Exception as err:
        print(f"Error: {err}")

elif flag == 17:
    try:
        college_name = input("Enter the csv file name to be imported")
        import_student_data('Student Management System','student')
    except Exception as err:
        print(f"Error: {err}")

elif flag == 18:
    try:
        student_name = input("Enter the student name")
        search_student_name('Student Management System','student',student_name)
    except Exception as err:
        print(f"Error: {err}")

if flag == 19:
    try:
        course_name = input("Enter the course name")
        search_course('Student Management System','student',course_name)
    except Exception as err:
        print(f"Error: {err}")

if flag == 20:
    try:
        teacher_name = input("Enter the teacher name")
        search_teacher_name('Student Management System','teacher',teacher_name)
    except Exception as err:
        print(f"Error: {err}")

if flag == 21:
    try:
        course_name = input("Enter the course name")
        search_course('Student Management System','teacher',course_name)
    except Exception as err:
        print(f"Error: {err}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 flag = int(input ('''
#       2                  Do you want to add new student? Press 1 \n
#       3                  Do you want to view student details? Press 2 \n
#       4                  Do you want to update student information? Press 3
#       5                  Do you want to delete student record? Press 4
#       6                  Do you want to list all students in the college? Press 5
#       7                  Do you want to assign course to each student (one student can have only 1 course? Press 6
#       8                  Do you want to view student's current course? Press 7
#       9                  Do you want to update student's current course (Only for 1st year students)? Press 8
# ...

# %%
fake = Faker()
student_data = [] 
for _ in range(8):  # Generate 20 rows of data
    course_id = fake.uuid4()
    course_name = fake.job()
    course_duration = fake.random_int(min=2, max=6)
    student_data.append((course_id, course_name, course_duration))

try:
    connection = mysql.connector.connect(
            host = 'localhost',
            user = 'root',
            password = 'Raveen123$',
            database = 'Student Management System'
        )
    print("connected")
except:
    print("not connected")
cursor = connection.cursor()
# query = "INSERT INTO course VALUES (%s, %s, %s)"
# cursor.executemany(query, student_data)
# connection.commit()
cursor.close()
connection.close()      

print(student_data)

# with open('new','w',newline='') as file:
#     csv_writer = csv.writer(file)
#     # csv_writer.writerow(['student_id', 'student_name', 'age', 'guardian', 'address', 'gender', 'mobile_number', 'college_name', 'branch', 'year', 'course_id', 'course_start_date', 'starting_date'])
#     for i in student_data:
#         csv_writer.writerow(i)
# Out:
# connected
# [('68078f25-2350-4f5a-b7c5-8829f8138cf3', 'Museum/gallery conservator', 6), ('2b73d907-aab0-4394-b53a-5ae914502cbd', 'Historic buildings inspector/conservation officer', 3), ('44fb04a6-63c2-40bd-979f-edcb6547529b', 'Commercial/residential surveyor', 4), ('e895e909-c788-4d37-8226-b274c33b4bbd', 'Buyer, retail', 5), ('ba074a58-08f7-4f51-ac6d-52e9ce787bd6', 'Secretary, company', 3), ('5191a58a-d958-4fcb-b85d-fdd7f847e19c', 'Curator', 6), ('a34fa4aa-dbe7-4970-9527-820f936b15aa', 'Immigration officer', 5), ('4bbd817b-454c-4225-94d7-a7d551e8a8ce', 'Holiday representative', 6)]
